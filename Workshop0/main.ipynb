# %% [markdown]
# # Workshop 0: Python Review
#
# ---
#
# ## Instructions:
#
# Welcome to this set of programming exercises! In this notebook, you will work through several coding challenges designed to test and strengthen your skills in various Python concepts, including image processing, `numpy`, `matplotlib`, and more.
#
# ### A Few Key Points:
# - **Turn off Gemini**: Google Colab has Gemini on by default; please first turn it off! `Tools > Settings > AI Assistance > Hide generative AI features`
# - **Take Your Time**: These exercises are designed to make you think critically about how to approach problems. Some may take time to fully understand and solve, and that’s perfectly fine!
# - **Do Your Best**: Focus on solving the problems to the best of your ability. It's okay if you don’t get everything perfect on your first try. The process of experimenting and learning from mistakes is the key.
# - **Feel Free to Consult Resources**: You can consult any resources you find useful, including documentation, tutorials, and even GPT! Use the tools at your disposal to help you learn and grow.
#
# ### Approach:
# - Read through each problem carefully and try to break it down into smaller parts.
# - Start with the simplest solution and improve it as you go.
# - If you feel stuck, take a step back, research, or ask for help (e.g., consult GPT, look at documentation, or search online).
# - Try to understand the logic behind each problem and practice solving them yourself, without rushing.
#
# ### Ready? Let’s get started!
#
# Good luck, and happy coding! 🚀
#
# (Yes, this was generated by ChatGPT)
#
# ---

# %% [markdown]
# ## Warmup: Built-in Python Libraries/Functions

# %% [markdown]
# ---
#
# ### Problem: Group Anagrams
#
# Write a function that takes a list of words and groups them into lists of anagrams. Two words are anagrams if they contain the same letters in the same frequency. The output should be a dictionary where the keys are sorted strings (to represent the anagram groups), and the values are lists of words that are anagrams of each other.
#
# #### Input:
# - A list of strings, `words`.
#
# #### Output:
# - A dictionary where each key is a tuple representing the sorted letters of an anagram group, and each value is a list of words that belong to that group.
#
# #### Tips:
# - For each word, sort its letters and use the sorted tuple as the dictionary key.
#
# ---

# %%
def group_anagrams(words: list[str]) -> dict[tuple[str], list[str]]:
    pass

words = ["listen", "silent", "enlist", "rat", "tar", "god", "dog"]

# Expected output:
# {
#     'eilnst': ["listen", "silent", "enlist"],
#     'art': ["rat", "tar"],
#     'dgo': ["god", "dog"]
# }

print(group_anagrams(words))

# %% [markdown]
# ---
#
# ### Problem: Find Unique Elements by Index Position in Multiple Lists
#
# Write a function that takes multiple lists of equal length and returns a new list, where each element is the unique value at that position across all input lists. If all values at a position are the same across the lists, include that value in the result. If values at a position differ, insert `None` in that position in the result.
#
# #### Requirements:
# 1. Use `zip` to solve the problem.
# 2. Avoid using any external libraries.
#
# #### Input:
# - A list of lists (e.g., `lists`), where each inner list has the same length.
#
# #### Output:
# - A single list containing either the unique value at each position (if all lists have the same value at that position) or `None` if there is a discrepancy.
#
# #### Tips:
# - Use `zip` to group elements by index positions across the input lists.
#
# ---

# %%
def unique_by_position(lists) -> list:
    pass

lists = [
    [1, 2, 3, 4],
    [1, 2, 5, 4],
    [1, 2, 3, 4]
]

# The values at each index:
# Index 0: [1, 1, 1] -> All are the same, so add 1
# Index 1: [2, 2, 2] -> All are the same, so add 2
# Index 2: [3, 5, 3] -> Different values, so add None
# Index 3: [4, 4, 4] -> All are the same, so add 4

print(unique_by_position(lists))  # Output should be [1, 2, None, 4]

# %% [markdown]
# ---
#
# ### Problem: Randomized Word Jumble
#
# Write a function that takes a sentence as input and returns a new sentence where the letters of each word (except the first and last letters) are shuffled randomly. This function should preserve the first and last letters of each word, while jumbling the letters in between.
#
# #### Requirements:
# 1. Use the regex module `re` to filter punctuation out of substrings.
# 2. Use the `random` module to shuffle the letters inside each word.
# 3. Maintain the original structure of the sentence and the positions of punctuation.
#
# #### Constraints:
# - If a word has only two letters or fewer, do not shuffle it.
# - Preserve the original spaces and punctuation in the sentence.
#
# #### Input:
# - A string, `sentence`, which may contain multiple words, spaces, and punctuation.
#
# #### Output:
# - A new string with each word's internal letters shuffled, while keeping the first and last letters in place.
#
# #### Tips:
# 1. Use the `random.shuffle()` function to shuffle characters.
# 2. Separate words from punctuation and only shuffle the characters that are between the first and last letter.
# 3. Reconstruct the sentence with shuffled words while keeping original spaces and punctuation intact.
#
# ---

# %%
import random
import re

def jumble_words(sentence: str) -> str:
    pass

sentence = "Hello, this is a jumbling exercise!"
# Possible output: "Hlelo, tihs is a jminubglg eireexcs!"

print(jumble_words(sentence))

# %% [markdown]
# ---
#
# ### Problem: Dataset Directory Structure Generator
#
# Write a Python function that creates a directory structure for a dataset and populates it with randomly generated `.txt` files. The function should take in a base directory path and then create a structure as follows:
#
# ```
# base_directory/
# ├── train/
# │   ├── a/
# │   │   ├── 80 text files with random strings of length 10
# │   └── b/
# │       ├── 80 text files with random strings of length 10
# ├── val/
# │   ├── a/
# │   │   ├── 10 text files with random strings of length 10
# │   └── b/
# │       ├── 10 text files with random strings of length 10
# └── test/
#     ├── a/
#     │   ├── 10 text files with random strings of length 10
#     └── b/
#         ├── 10 text files with random strings of length 10
# ```
#
# #### Requirements:
# 1. Use `itertools` to help iterate over filepaths.
# 2. Use the `os` module to create directories and paths.
# 3. Use the `shutil` module to clean up and re-create the base directory if it already exists.
# 4. Generate a total of 200 `.txt` files with random 10-character strings, and write one string in each file.
#
# #### Details:
# - Create a base directory, e.g., `dataset/`, with subdirectories `train/`, `val/`, and `test/`.
# - Each subdirectory (`train`, `val`, `test`) should contain two folders, `a` and `b`.
#   - In `train/a` and `train/b`, create 80 text files each.
#   - In `val/a` and `val/b`, create 10 text files each.
#   - In `test/a` and `test/b`, create 10 text files each.
# - Each file should contain a single line of randomly generated letters of length 10.
#
# ### Example of Generated Text File Content:
# Each `.txt` file should contain a random 10-letter string, such as:
# ```
# Xyzqpbaclt
# ```
# ```
# arioplKjhd
# ```
#
# #### Tips:
# 1. Use `os.makedirs()` to create the directory structure.
# 2. Use `shutil.rmtree()` to delete the base directory if it already exists.
# 3. Use `itertools.product()` to iterate over all possible directories.
# 4. Use `random.choices()` from the `random` module to generate a 10-character string.
#
# ---

# %%
import os
import shutil
import itertools
import random

random.seed(0)
ALL_LETTERS = 'abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ'

def create_dataset_structure(base_directory: str) -> None:
    pass

create_dataset_structure("dataset")
create_dataset_structure("dataset")

# %% [markdown]
# ---
#
# ### Problem: Letter Frequency Analysis in Dataset
#
# Write a function that reads through each text file in the dataset structure created in the previous problem, counts the frequency of each letter (A-Z, case-insensitive) in each file, and aggregates the total frequency count for each letter across all files. Your function should return a dictionary containing the total count of each letter in the entire dataset.
#
# #### Requirements:
# 1. Use `itertools` to help iterate over files and accumulate counts across files.
# 2. Use `collections.Counter` to count letter occurrences in each file and to aggregate these counts across all files.
#
# #### Steps:
# 1. Traverse through the entire dataset directory structure, reading each `.txt` file.
# 2. For each file, count the frequency of each letter in the file (case-insensitive) using `Counter`.
# 3. Accumulate the counts from each file into a single `Counter` object that stores the total count of each letter across the whole dataset.
# 4. Return the final letter frequency as a dictionary, where the keys are letters and values are their total counts.
#
# #### Constraints:
# - Only consider letters A-Z (case-insensitive).
# - Ensure the function performs efficiently by accumulating counts directly from each file into a single `Counter`.
#
# #### Tips:
# 1. Use `itertools.product()` to iterate over all possible directories.
# 2. Use `Counter.update()` to aggregate counts from each file.
# 3. Use `os` to walk through the directory and access each `.txt` file in the dataset.
#
# ---

# %%
import os
from collections import Counter

def count_letter_frequency(base_directory: str) -> dict[str, int]:
    pass

# Example function call
letter_counts = count_letter_frequency("dataset")

# Expected output (values will vary based on the random strings in the dataset)
# {
#     'A': 158,
#     'B': 142,
#     'C': 170,
#     ...
#     'Z': 96
# }

# %% [markdown]
# ## NumPy and Convolutions
#
# ### Interesting Watch
#
# [But what is a convolution? (3Blue1Brown)](https://www.youtube.com/watch?v=KuXjwB4LzSA&ab_channel=3Blue1Brown)
#
# ### Problem Setup: Download Image
#
# Run the following cell to download the image for the next problem:

# %%
import requests
import numpy as np
from PIL import Image
from io import BytesIO
import matplotlib.pyplot as plt

def download_image(url):
    response = requests.get(url)
    img = Image.open(BytesIO(response.content))
    img_array = np.array(img.convert('L'))
    return img_array

url = 'https://preview.redd.it/they-gambin-v0-53l8uq7ruxzd1.jpeg?width=1080&crop=smart&auto=webp&s=da8c1a51b9a2936826d9aecb224d6256dfe914d5'
image = download_image(url)
plt.imshow(image, cmap='gray')
plt.axis('off')
plt.show()

image.shape
# Out:
# (810, 1080)

# %% [markdown]
# ---
#
# ### Problem: Image Convolution with Custom Kernel
#
# Write a function that performs a 2D convolution operation on a grayscale image represented as a `numpy` array. The function should accept an image array and a kernel array, and return the convolved image array.
#
# #### Requirements:
# 1. Use only `numpy` operations to implement the convolution.
# 2. Avoid using external libraries for convolution (like `scipy.ndimage` or `opencv`).
# 3. Properly handle image boundaries by applying zero-padding before the convolution.
#
# #### Details:
# - Convolution is an operation where each pixel in the image is replaced by a weighted sum of its neighboring pixels, determined by the kernel. In this exercise, apply the kernel over every pixel (including boundaries with padding).
# - You can assume the image is a 2D `numpy` array of shape `(H, W)` with pixel values between 0 and 255.
# - The kernel will be a smaller 2D `numpy` array of odd shape `(k, k)` (e.g., 3x3, 5x5).
#
# #### Steps:
# 1. **Padding**: Add zero-padding to the image so that the output image has the same dimensions as the input image.
# 2. **Convolution Operation**:
#    - For each pixel in the original image, calculate the dot product between the kernel and the corresponding region in the padded image.
#    - Store the result in the corresponding position in the output array.
# 3. **Return the Result**: Return the convolved image as a `numpy` array with the same dimensions as the original image.
#
# #### Input:
# - A 2D `numpy` array `image` of shape `(H, W)`, representing the grayscale image.
# - A 2D `numpy` array `kernel` of shape `(k, k)`, representing the convolution kernel.
#
# #### Output:
# - A 2D `numpy` array with the same shape as the input image.
#
# #### Tips:
# 1. **Padding**: Use `np.pad` to add zero-padding around the image.
# 2. **Iterate Efficiently**: Use nested loops with `numpy` slicing to apply the kernel to each region.
# 3. **Apply Kernel**: Use `numpy` element-wise multiplication and `np.sum()` to apply the kernel to each local region of the image.
# 4. **Output Array**: Initialize the output array with the same dimensions as the input image to store convolution results.
#
# ---

# %%
import numpy as np

def convolve_2d(image, kernel):
    pass

kernel = np.array([
    [1, 0, -1],
    [1, 0, -1],
    [1, 0, -1]
])

# Call the function
convolved_image = convolve_2d(image, kernel)

# Expected output (values may vary based on kernel):
# array with convolved values such as
# [[...], [...], [...], [...]]
print(convolved_image)

# %% [markdown]
# ## Matplotlib

# %% [markdown]
# ---
#
# ### Problem: Visualizing Image Convolution with Matplotlib
#
# Write a function that applies a convolution filter to a grayscale image using `numpy` and then displays both the original and convolved images side-by-side using `matplotlib`. This function should allow you to visualize how the convolution kernel transforms the image.
#
# #### Requirements:
# 1. Use the `numpy` function from the previous problem to apply the convolution.
# 2. Use `matplotlib` to display the original image and the convolved image side-by-side.
# 3. Include color maps and titles for each image.
#
# #### Details:
# - You can assume the input image is a 2D grayscale `numpy` array with pixel values between 0 and 255.
# - The kernel is also a 2D `numpy` array, representing the convolution filter to be applied.
# - Display the two images side-by-side with appropriate titles and color maps using `matplotlib`.
#
# #### Steps:
# 1. **Apply Convolution**: Use the convolution function from the previous exercise to produce the convolved image.
# 2. **Display Images**: Use `matplotlib.pyplot` to create a figure with two subplots:
#    - The left subplot should show the original image.
#    - The right subplot should show the convolved image.
# 3. **Customization**:
#    - Use `gray` color map for both images to maintain grayscale visualization.
#    - Add titles for each subplot to indicate "Original Image" and "Convolved Image".
#
# #### Input:
# - A 2D `numpy` array `image` of shape `(H, W)`, representing the grayscale image.
# - A 2D `numpy` array `kernel` of shape `(k, k)`, representing the convolution kernel.
#
# #### Output:
# - A `matplotlib` plot with the original and convolved images displayed side-by-side.
#
# #### Expected Visualization:
# A side-by-side plot showing the original image on the left and the convolved image on the right.
#
# #### Tips:
# 1. **Matplotlib Setup**: Use `plt.subplots(1, 2, figsize=(10, 5))` to create two subplots in a single row.
# 2. **Color Map**: Use `plt.imshow(..., cmap='gray')` to display images in grayscale.
# 3. **Title and Axis Settings**: Use `ax.set_title()` and `ax.axis('off')` to label each subplot and remove axes.
#
# ---

# %%
import numpy as np
import matplotlib.pyplot as plt
import requests
from PIL import Image
from io import BytesIO

def plot_convolution(image, convolved_image, kernel):
    pass

# Function call
plot_convolution(image, convolved_image, kernel)
